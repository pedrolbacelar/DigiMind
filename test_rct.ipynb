# %%
from dtwinpy.Digital_Twin import Digital_Twin
mydt = Digital_Twin(name= "rct", targeted_part_id= 3)
mymodel = mydt.generate_digital_model()
mymodel.run()
# Out:
# Deleting existing model (excepted by 'initial.json') from the relative folder path:'models/rct'
# Done! Deleted 0 successfuly
# exp_database_path: databases/rct/exp_database.db
# --- printing databases paths ---
# Digital Database: 'databases/rct/digital_database.db'
# Real Database: 'databases/rct/real_database.db'
# ID Database: 'databases/rct/ID_database.db'
# IP address not provided, Broker Manager not created. Considering an offiline enviorment
# 30 March 23:10:15 |---- Digital Twin 'rct' created sucessfully ----
# ### ============ Simulation Started ============ ###
# Time: 0 - [Machine 1] got Part 1 from Queue 1 (capacity= 11)
# Time: 0 - [Machine 2] got Part 13 from Queue 2 (capacity= 2)
# Time: 0 - [Machine 3] got Part 16 from Queue 3 (capacity= 2)
# ! Using 'alternated' policy to allocate Part 1 to Queue 2
# Time: 11 - [Conveyor towards Queue 2] GOT Part 1
# Time: 11 - [Machine 1] got Part 2 from Queue 1 (capacity= 10)
# ...

# %%
result = mymodel.calculate_RCT(part_id_selected= 3)
print(result)
# Out:
# > Predicting RCT for Part 3...
# > RCT for Part 3: 182
# 182
